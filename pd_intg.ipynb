# %%
from IPhreeqcPy import IPhreeqc
a = IPhreeqc()
a.SetOutputStringOn()
a.LoadDatabase('wateq4f.dat')
a.RunFile('tut1.in')

# %%
o = str(a.GetOutputString())[2:-1]
o1 = o.replace('\\n','\n')
o2 = o1.replace('\\t','\t')

# %%
print(o2)
# Out:
# ------------------------------------
# Reading input data for simulation 1.
# ------------------------------------
#
# 	TITLE Example 1.--Add uranium and speciate seawater.
# 	SOLUTION 1  SEAWATER FROM NORDSTROM AND OTHERS (1979)
# 	        units   ppm
# 	        pH      8.22
# 	        pe      8.451
# 	        density 1.023
# 	        temp    25.0
# 	        redox   O(0)/O(-2)
# 	        Ca              412.3
# 	        Mg              1291.8
# 	        Na              10768.0
# 	        K               399.1
# 	        Fe              0.002
# 	        Mn              0.0002  pe
# 	        Si              4.28
# 	        Cl              19353.0
# 	        Alkalinity      141.682 as HCO3
# 	        S(6)            2712.0
# 	        N(5)            0.29    gfw   62.0
# 	        N(-3)           0.03    as    NH4
# 	        U               3.3     ppb   N(5)/N(-3)
# 	        O(0)            1.0     O2(g) -0.7
# 	SOLUTION_MASTER_SPECIES
# ...

# %%
with open("outy.txt","w") as f:
    f.write(o2)

# %%
import pandas as pd

# %%
tabl = pd.read_table('outy.txt', names=[str(i) for i in range(20)],sep='\s+',header=None)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-4745c04229ea> in <module>()
# ----> 1 tabl = pd.read_table('outy.txt', names=[str(i) for i in range(20)],sep='\s+',header=None)
#
# NameError: name 'pd' is not defined

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/p3/p3env/lib/python3.5/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2441             try:
# -> 2442                 return self._engine.get_loc(key)
#    2443             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas/_libs/index.c:5280)()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas/_libs/index.c:5126)()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas/_libs/hashtable.c:20523)()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas/_libs/hashtable.c:20477)()
#
# KeyError: 100
#
# During handling of the above exception, another exception occurred:
#
# ...
