# %%
from IPhreeqcPy import IPhreeqc

# %%
a = IPhreeqc()

# %%
a.SetOutputStringOn()
a.LoadDatabase('wateq4f.dat')

# %%
a.RunFile('tut1.in')

# %%
type(a.GetOutputString())
# Out:
# bytes

# %%
b = a.GetOutputString()

# %%
b
# Out:
# b'------------------------------------\nReading input data for simulation 1.\n------------------------------------\n\n\tTITLE Example 1.--Add uranium and speciate seawater.\n\tSOLUTION 1  SEAWATER FROM NORDSTROM AND OTHERS (1979)\n\t        units   ppm\n\t        pH      8.22\n\t        pe      8.451\n\t        density 1.023\n\t        temp    25.0\n\t        redox   O(0)/O(-2)\n\t        Ca              412.3\n\t        Mg              1291.8\n\t        Na              10768.0\n\t        K               399.1\n\t        Fe              0.002\n\t        Mn              0.0002  pe\n\t        Si              4.28\n\t        Cl              19353.0\n\t        Alkalinity      141.682 as HCO3\n\t        S(6)            2712.0\n\t        N(5)            0.29    gfw   62.0\n\t        N(-3)           0.03    as    NH4\n\t        U               3.3     ppb   N(5)/N(-3)\n\t        O(0)            1.0     O2(g) -0.7\n\tSOLUTION_MASTER_SPECIES\n\t        U       U+4     0.0     238.0290     238
# ...

# %%
with open("out.txt", "w") as f:
    f.write("".format(b))

# %%
type(b)
# Out:
# bytes

# %%
b.title()
# Out:
# b'------------------------------------\nReading Input Data For Simulation 1.\n------------------------------------\n\n\tTitle Example 1.--Add Uranium And Speciate Seawater.\n\tSolution 1  Seawater From Nordstrom And Others (1979)\n\t        Units   Ppm\n\t        Ph      8.22\n\t        Pe      8.451\n\t        Density 1.023\n\t        Temp    25.0\n\t        Redox   O(0)/O(-2)\n\t        Ca              412.3\n\t        Mg              1291.8\n\t        Na              10768.0\n\t        K               399.1\n\t        Fe              0.002\n\t        Mn              0.0002  Pe\n\t        Si              4.28\n\t        Cl              19353.0\n\t        Alkalinity      141.682 As Hco3\n\t        S(6)            2712.0\n\t        N(5)            0.29    Gfw   62.0\n\t        N(-3)           0.03    As    Nh4\n\t        U               3.3     Ppb   N(5)/N(-3)\n\t        O(0)            1.0     O2(G) -0.7\n\tSolution_Master_Species\n\t        U       U+4     0.0     238.0290     238
# ...

# %%
b.strip()
# Out:
# b'------------------------------------\nReading input data for simulation 1.\n------------------------------------\n\n\tTITLE Example 1.--Add uranium and speciate seawater.\n\tSOLUTION 1  SEAWATER FROM NORDSTROM AND OTHERS (1979)\n\t        units   ppm\n\t        pH      8.22\n\t        pe      8.451\n\t        density 1.023\n\t        temp    25.0\n\t        redox   O(0)/O(-2)\n\t        Ca              412.3\n\t        Mg              1291.8\n\t        Na              10768.0\n\t        K               399.1\n\t        Fe              0.002\n\t        Mn              0.0002  pe\n\t        Si              4.28\n\t        Cl              19353.0\n\t        Alkalinity      141.682 as HCO3\n\t        S(6)            2712.0\n\t        N(5)            0.29    gfw   62.0\n\t        N(-3)           0.03    as    NH4\n\t        U               3.3     ppb   N(5)/N(-3)\n\t        O(0)            1.0     O2(g) -0.7\n\tSOLUTION_MASTER_SPECIES\n\t        U       U+4     0.0     238.0290     238
# ...

# %%
d = (str(b))

# %%
with open("out2.txt", "w") as f:
    f.write(d)

# %%
d.split()
# Out:
# ["b'------------------------------------\\nReading",
#  'input',
#  'data',
#  'for',
#  'simulation',
#  '1.\\n------------------------------------\\n\\n\\tTITLE',
#  'Example',
#  '1.--Add',
#  'uranium',
#  'and',
#  'speciate',
#  'seawater.\\n\\tSOLUTION',
#  '1',
#  'SEAWATER',
#  'FROM',
#  'NORDSTROM',
#  'AND',
#  'OTHERS',
#  '(1979)\\n\\t',
#  'units',
#  'ppm\\n\\t',
#  'pH',
#  '8.22\\n\\t',
#  'pe',
#  '8.451\\n\\t',
#  'density',
#  '1.023\\n\\t',
#  'temp',
#  '25.0\\n\\t',
#  'redox',
#  'O(0)/O(-2)\\n\\t',
#  'Ca',
#  '412.3\\n\\t',
#  'Mg',
#  '1291.8\\n\\t',
#  'Na',
#  '10768.0\\n\\t',
#  'K',
#  '399.1\\n\\t',
#  'Fe',
#  '0.002\\n\\t',
#  'Mn',
#  '0.0002',
#  'pe\\n\\t',
#  'Si',
#  '4.28\\n\\t',
#  'Cl',
#  '19353.0\\n\\t',
#  'Alkalinity',
#  '141.682',
#  'as',
#  'HCO3\\n\\t',
#  'S(6)',
#  '2712.0\\n\\t',
#  'N(5)',
#  '0.29',
#  'gfw',
#  '62.0\\n\\t',
#  'N(-3)',
#  '0.03',
#  'as',
#  'NH4\\n\\t',
#  'U',
#  '3.3',
#  'ppb',
#  'N(5)/N(-3)\\n\\t',
# ...

# %%
d.encode("utf-8")
# Out:
# b"b'------------------------------------\\nReading input data for simulation 1.\\n------------------------------------\\n\\n\\tTITLE Example 1.--Add uranium and speciate seawater.\\n\\tSOLUTION 1  SEAWATER FROM NORDSTROM AND OTHERS (1979)\\n\\t        units   ppm\\n\\t        pH      8.22\\n\\t        pe      8.451\\n\\t        density 1.023\\n\\t        temp    25.0\\n\\t        redox   O(0)/O(-2)\\n\\t        Ca              412.3\\n\\t        Mg              1291.8\\n\\t        Na              10768.0\\n\\t        K               399.1\\n\\t        Fe              0.002\\n\\t        Mn              0.0002  pe\\n\\t        Si              4.28\\n\\t        Cl              19353.0\\n\\t        Alkalinity      141.682 as HCO3\\n\\t        S(6)            2712.0\\n\\t        N(5)            0.29    gfw   62.0\\n\\t        N(-3)           0.03    as    NH4\\n\\t        U               3.3     ppb   N(5)/N(-3)\\n\\t        O(0)            1.0     O2(g) -0.7\\n\\tSOLUTION_MASTER_SPECIES\
# ...

# %%
print(d)
# Out:
# b'------------------------------------\nReading input data for simulation 1.\n------------------------------------\n\n\tTITLE Example 1.--Add uranium and speciate seawater.\n\tSOLUTION 1  SEAWATER FROM NORDSTROM AND OTHERS (1979)\n\t        units   ppm\n\t        pH      8.22\n\t        pe      8.451\n\t        density 1.023\n\t        temp    25.0\n\t        redox   O(0)/O(-2)\n\t        Ca              412.3\n\t        Mg              1291.8\n\t        Na              10768.0\n\t        K               399.1\n\t        Fe              0.002\n\t        Mn              0.0002  pe\n\t        Si              4.28\n\t        Cl              19353.0\n\t        Alkalinity      141.682 as HCO3\n\t        S(6)            2712.0\n\t        N(5)            0.29    gfw   62.0\n\t        N(-3)           0.03    as    NH4\n\t        U               3.3     ppb   N(5)/N(-3)\n\t        O(0)            1.0     O2(g) -0.7\n\tSOLUTION_MASTER_SPECIES\n\t        U       U+4     0.0     238.0290     238
# ...

# %%
print(b.expandtabs())
# Out:
# b'------------------------------------\nReading input data for simulation 1.\n------------------------------------\n\n        TITLE Example 1.--Add uranium and speciate seawater.\n        SOLUTION 1  SEAWATER FROM NORDSTROM AND OTHERS (1979)\n                units   ppm\n                pH      8.22\n                pe      8.451\n                density 1.023\n                temp    25.0\n                redox   O(0)/O(-2)\n                Ca              412.3\n                Mg              1291.8\n                Na              10768.0\n                K               399.1\n                Fe              0.002\n                Mn              0.0002  pe\n                Si              4.28\n                Cl              19353.0\n                Alkalinity      141.682 as HCO3\n                S(6)            2712.0\n                N(5)            0.29    gfw   62.0\n                N(-3)           0.03    as    NH4\n                U               3.3     ppb   N(5)/N(-3
# ...

# %%
b.strip()
# Out:
# b'------------------------------------\nReading input data for simulation 1.\n------------------------------------\n\n\tTITLE Example 1.--Add uranium and speciate seawater.\n\tSOLUTION 1  SEAWATER FROM NORDSTROM AND OTHERS (1979)\n\t        units   ppm\n\t        pH      8.22\n\t        pe      8.451\n\t        density 1.023\n\t        temp    25.0\n\t        redox   O(0)/O(-2)\n\t        Ca              412.3\n\t        Mg              1291.8\n\t        Na              10768.0\n\t        K               399.1\n\t        Fe              0.002\n\t        Mn              0.0002  pe\n\t        Si              4.28\n\t        Cl              19353.0\n\t        Alkalinity      141.682 as HCO3\n\t        S(6)            2712.0\n\t        N(5)            0.29    gfw   62.0\n\t        N(-3)           0.03    as    NH4\n\t        U               3.3     ppb   N(5)/N(-3)\n\t        O(0)            1.0     O2(g) -0.7\n\tSOLUTION_MASTER_SPECIES\n\t        U       U+4     0.0     238.0290     238
# ...

# %%
str(b.expandtabs())
# Out:
# "b'------------------------------------\\nReading input data for simulation 1.\\n------------------------------------\\n\\n        TITLE Example 1.--Add uranium and speciate seawater.\\n        SOLUTION 1  SEAWATER FROM NORDSTROM AND OTHERS (1979)\\n                units   ppm\\n                pH      8.22\\n                pe      8.451\\n                density 1.023\\n                temp    25.0\\n                redox   O(0)/O(-2)\\n                Ca              412.3\\n                Mg              1291.8\\n                Na              10768.0\\n                K               399.1\\n                Fe              0.002\\n                Mn              0.0002  pe\\n                Si              4.28\\n                Cl              19353.0\\n                Alkalinity      141.682 as HCO3\\n                S(6)            2712.0\\n                N(5)            0.29    gfw   62.0\\n                N(-3)           0.03    as    NH4\\n                U             
# ...

# %%
b.decode('utf8')
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-46-ff95bc0b492f> in <module>()
# ----> 1 b.decode('utf8')
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xb0 in position 4019: invalid start byte

# %%
q = str(b)

# %%
o = q[2:]

# %%
o.encode('utf8')
# Out:
# b"------------------------------------\\nReading input data for simulation 1.\\n------------------------------------\\n\\n\\tTITLE Example 1.--Add uranium and speciate seawater.\\n\\tSOLUTION 1  SEAWATER FROM NORDSTROM AND OTHERS (1979)\\n\\t        units   ppm\\n\\t        pH      8.22\\n\\t        pe      8.451\\n\\t        density 1.023\\n\\t        temp    25.0\\n\\t        redox   O(0)/O(-2)\\n\\t        Ca              412.3\\n\\t        Mg              1291.8\\n\\t        Na              10768.0\\n\\t        K               399.1\\n\\t        Fe              0.002\\n\\t        Mn              0.0002  pe\\n\\t        Si              4.28\\n\\t        Cl              19353.0\\n\\t        Alkalinity      141.682 as HCO3\\n\\t        S(6)            2712.0\\n\\t        N(5)            0.29    gfw   62.0\\n\\t        N(-3)           0.03    as    NH4\\n\\t        U               3.3     ppb   N(5)/N(-3)\\n\\t        O(0)            1.0     O2(g) -0.7\\n\\tSOLUTION_MASTER_SPECIES\\n
# ...

# %%
z = o[:-1]

# %%
o.replace("
# Out:
#   File "<ipython-input-59-c2ff27a47749>", line 1
#     o.replace("\\\","\\")
#                          ^
# SyntaxError: unexpected character after line continuation character

# %%
type(o)
# Out:
# str

# %%
o
# Out:
# "------------------------------------\\nReading input data for simulation 1.\\n------------------------------------\\n\\n\\tTITLE Example 1.--Add uranium and speciate seawater.\\n\\tSOLUTION 1  SEAWATER FROM NORDSTROM AND OTHERS (1979)\\n\\t        units   ppm\\n\\t        pH      8.22\\n\\t        pe      8.451\\n\\t        density 1.023\\n\\t        temp    25.0\\n\\t        redox   O(0)/O(-2)\\n\\t        Ca              412.3\\n\\t        Mg              1291.8\\n\\t        Na              10768.0\\n\\t        K               399.1\\n\\t        Fe              0.002\\n\\t        Mn              0.0002  pe\\n\\t        Si              4.28\\n\\t        Cl              19353.0\\n\\t        Alkalinity      141.682 as HCO3\\n\\t        S(6)            2712.0\\n\\t        N(5)            0.29    gfw   62.0\\n\\t        N(-3)           0.03    as    NH4\\n\\t        U               3.3     ppb   N(5)/N(-3)\\n\\t        O(0)            1.0     O2(g) -0.7\\n\\tSOLUTION_MASTER_SPECIES\\n\
# ...

# %%
z
# Out:
# ------------------------------------\nReading input data for simulation 1.\n------------------------------------\n\n\tTITLE Example 1.--Add uranium and speciate seawater.\n\tSOLUTION 1  SEAWATER FROM NORDSTROM AND OTHERS (1979)\n\t        units   ppm\n\t        pH      8.22\n\t        pe      8.451\n\t        density 1.023\n\t        temp    25.0\n\t        redox   O(0)/O(-2)\n\t        Ca              412.3\n\t        Mg              1291.8\n\t        Na              10768.0\n\t        K               399.1\n\t        Fe              0.002\n\t        Mn              0.0002  pe\n\t        Si              4.28\n\t        Cl              19353.0\n\t        Alkalinity      141.682 as HCO3\n\t        S(6)            2712.0\n\t        N(5)            0.29    gfw   62.0\n\t        N(-3)           0.03    as    NH4\n\t        U               3.3     ppb   N(5)/N(-3)\n\t        O(0)            1.0     O2(g) -0.7\n\tSOLUTION_MASTER_SPECIES\n\t        U       U+4     0.0     238.0290     238.0
# ...

# %%
a = "hello bob\'s"

# %%
a
# Out:
# "hello bob's"

# %%
b = "hello bob\s"

# %%
type(b)
# Out:
# str

# %%
b = 'hey \\n hey'

# %%
print(b)
# Out:
# hey \n hey

# %%
c = 'lurk\s lurk'

# %%
c
# Out:
# 'lurk\\s lurk'

# %%
b
# Out:
# 'hey \\n hey'

# %%
j = b.replace('\\n','\n')

# %%
j
# Out:
# 'hey \n hey'

# %%
o1 = o.replace('\\n','\n')

# %%
o2 = o1.replace('\\t','\t')

# %%
print(o2)
# Out:
# ------------------------------------
# Reading input data for simulation 1.
# ------------------------------------
#
# 	TITLE Example 1.--Add uranium and speciate seawater.
# 	SOLUTION 1  SEAWATER FROM NORDSTROM AND OTHERS (1979)
# 	        units   ppm
# 	        pH      8.22
# 	        pe      8.451
# 	        density 1.023
# 	        temp    25.0
# 	        redox   O(0)/O(-2)
# 	        Ca              412.3
# 	        Mg              1291.8
# 	        Na              10768.0
# 	        K               399.1
# 	        Fe              0.002
# 	        Mn              0.0002  pe
# 	        Si              4.28
# 	        Cl              19353.0
# 	        Alkalinity      141.682 as HCO3
# 	        S(6)            2712.0
# 	        N(5)            0.29    gfw   62.0
# 	        N(-3)           0.03    as    NH4
# 	        U               3.3     ppb   N(5)/N(-3)
# 	        O(0)            1.0     O2(g) -0.7
# 	SOLUTION_MASTER_SPECIES
# ...

# %%
with open("outy.txt","w") as f:
    f.write(o2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-abe53a69be73> in <module>()
#       1 with open("outy.txt","w") as f:
# ----> 2     f.write(o2)
#
# NameError: name 'o2' is not defined

# %%
import pandas as pd

# %%
pd.read_csv(, names=[str(i) for i in range(100)]
